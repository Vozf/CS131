# %%
import cv2
from PIL import Image
from matplotlib import pyplot as plt

# %%
path = 'old_shad.png'
orig_mask = cv2.imread(path, cv2.IMREAD_UNCHANGED)[..., 3]
# orig_mask = orig_mask / 255
print(orig_mask.shape)
plt.imshow(orig_mask)
# Out:
# (812, 1196)
